# %%
import pandas as pd
import re

# %%
ext = (".xls", ".xlsx")
file = 'People.csv'
if(file.endswith(ext)):
    # Code for XLS
    df = pd.read_excel(file)
else:
    # Code for CSV
    df = pd.read_csv(file, sep=',',  engine='python', error_bad_lines=False)

# %%
df = pd.read_csv('People.csv')
df1 = pd.read_json('People.json')

# %%
df.head()
# Out:
#    person_ID                 name    first    last  middle             email  \
# 0       3130      Burks, Rosella   Rosella   Burks     NaN   BurksR@univ.edu
# 1       3297       Avila, Damien    Damien   Avila     NaN   AvilaD@univ.edu
# 2       3547        Olsen, Robin     Robin   Olsen     NaN   OlsenR@univ.edu
# 3       1538  Moises, Edgar Estes    Edgar  Moises   Estes  MoisesE@univ.edu
# 4       2941  Brian, Heath Pruitt    Heath   Brian  Pruitt   BrianH@univ.edu
#
#                phone           fax                title
# 0       963.555.1253  963.777.4065           Professor
# 1       963.555.1352  963.777.7914           Professor
# 2       963.555.1378  963.777.9262  Assistant Professor
# 3  963.555.2731x3565  963.777.8264            Professor
# 4       963.555.2800  963.777.7249   Associate Curator

# %%
df1.head()
# Out:
#               email           fax    first    last  middle  \
# 0   BurksR@univ.edu  963.777.4065  Rosella   Burks
# 1   AvilaD@univ.edu  963.777.7914   Damien   Avila
# 2   OlsenR@univ.edu  963.777.9262    Robin   Olsen
# 3  MoisesE@univ.edu  963.777.8264    Edgar  Moises   Estes
# 4   BrianH@univ.edu  963.777.7249    Heath   Brian  Pruitt
#
#                   name  person_ID              phone                title
# 0      Burks, Rosella        3130       963.555.1253           Professor
# 1       Avila, Damien        3297       963.555.1352           Professor
# 2        Olsen, Robin        3547       963.555.1378  Assistant Professor
# 3  Moises, Edgar Estes       1538  963.555.2731x3565            Professor
# 4  Brian, Heath Pruitt       2941       963.555.2800   Associate Curator

# %%
# Here first we need to change the arrange the column
columns = list(df.columns)
df1 = df1[columns]

# %%
df1.head()
# Out:
#    person_ID                 name    first    last  middle             email  \
# 0       3130      Burks, Rosella   Rosella   Burks           BurksR@univ.edu
# 1       3297       Avila, Damien    Damien   Avila           AvilaD@univ.edu
# 2       3547        Olsen, Robin     Robin   Olsen           OlsenR@univ.edu
# 3       1538  Moises, Edgar Estes    Edgar  Moises   Estes  MoisesE@univ.edu
# 4       2941  Brian, Heath Pruitt    Heath   Brian  Pruitt   BrianH@univ.edu
#
#                phone           fax                title
# 0       963.555.1253  963.777.4065           Professor
# 1       963.555.1352  963.777.7914           Professor
# 2       963.555.1378  963.777.9262  Assistant Professor
# 3  963.555.2731x3565  963.777.8264            Professor
# 4       963.555.2800  963.777.7249   Associate Curator

# %%
intersected_df = pd.merge(df, df1, how='inner')

# %%
intersected_df
# Out:
#     person_ID                        name      first      last      middle  \
# 0        1538         Moises, Edgar Estes      Edgar    Moises       Estes
# 1        2941         Brian, Heath Pruitt      Heath     Brian      Pruitt
# 2        2401         Claude, Elvin Haney      Elvin    Claude       Haney
# 3        2561        Derek, Antoine Mccoy    Antoine     Derek       Mccoy
# 4        2755       Kendrick, Reba Alford       Reba  Kendrick      Alford
# 5        2096          Chuck, Lloyd Haney      Lloyd     Chuck       Haney
# 6        2948  Baxter, Johnathan Browning  Johnathan    Baxter    Browning
# 7        2811   Deirdre, Florence Barrera   Florence   Deirdre     Barrera
# 8        4580     Fernando, Toby Calderon       Toby  Fernando    Calderon
# 9        2254         Effie, Leila Vinson      Leila     Effie      Vinson
# 10       2217        Katheryn, Ruben Holt      Ruben  Katheryn        Holt
# ...

# %%
# df is not in df1
df[~df.apply(tuple,1).isin(df1.apply(tuple,1))]
# Out:
#     person_ID                name     first      last middle  \
# 0        3130     Burks, Rosella    Rosella     Burks    NaN
# 1        3297      Avila, Damien     Damien     Avila    NaN
# 2        3547       Olsen, Robin      Robin     Olsen    NaN
# 6        2070     Mosley, Edmund     Edmund    Mosley    NaN
# 8        1625    Hawkins, Callie     Callie   Hawkins    NaN
# 9        1307       Pate, Andrea     Andrea      Pate    NaN
# 10       2342        Austin, Liz        Liz    Austin    NaN
# 12       4150     Sims, Angelina   Angelina      Sims    NaN
# 13       3544  Mullins, Kimberly   Kimberly   Mullins    NaN
# 15       1089     Payne, Ladonna    Ladonna     Payne    NaN
# 17       4539     Weiss, Gilbert    Gilbert     Weiss    NaN
# 20       2895  Garrison, Patrica    Patrica  Garrison    NaN
# 22       2389      Buckley, Rose       Rose   Buckley    NaN
# 23       1699    Stanton, Kathie     Kathie   Stanton    NaN
# ...

# %%
#df is in df1
df[df.apply(tuple,1).isin(df1.apply(tuple,1))]
# Out:
#     person_ID                        name      first      last      middle  \
# 3        1538         Moises, Edgar Estes      Edgar    Moises       Estes
# 4        2941         Brian, Heath Pruitt      Heath     Brian      Pruitt
# 5        2401         Claude, Elvin Haney      Elvin    Claude       Haney
# 7        2561        Derek, Antoine Mccoy    Antoine     Derek       Mccoy
# 11       2755       Kendrick, Reba Alford       Reba  Kendrick      Alford
# 14       2096          Chuck, Lloyd Haney      Lloyd     Chuck       Haney
# 16       2948  Baxter, Johnathan Browning  Johnathan    Baxter    Browning
# 18       2811   Deirdre, Florence Barrera   Florence   Deirdre     Barrera
# 19       4580     Fernando, Toby Calderon       Toby  Fernando    Calderon
# 21       2254         Effie, Leila Vinson      Leila     Effie      Vinson
# 27       2217        Katheryn, Ruben Holt      Ruben  Katheryn        Holt
# ...
